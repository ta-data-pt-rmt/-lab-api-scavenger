# %% [markdown]
# ### Your lab resolution :

# %% [markdown]
# ## First response
#
# {
#   "login": "gonzalo711",
#   "id": 44572646,
#   "node_id": "MDQ6VXNlcjQ0NTcyNjQ2",
#   "avatar_url": "https://avatars.githubusercontent.com/u/44572646?v=4",
#   "gravatar_id": "",
#   "url": "https://api.github.com/users/gonzalo711",
#   "html_url": "https://github.com/gonzalo711",
#   "followers_url": "https://api.github.com/users/gonzalo711/followers",
#   "following_url": "https://api.github.com/users/gonzalo711/following{/other_user}",
#   "gists_url": "https://api.github.com/users/gonzalo711/gists{/gist_id}",
#   "starred_url": "https://api.github.com/users/gonzalo711/starred{/owner}{/repo}",
#   "subscriptions_url": "https://api.github.com/users/gonzalo711/subscriptions",
#   "organizations_url": "https://api.github.com/users/gonzalo711/orgs",
#   "repos_url": "https://api.github.com/users/gonzalo711/repos",
#   "events_url": "https://api.github.com/users/gonzalo711/events{/privacy}",
#   "received_events_url": "https://api.github.com/users/gonzalo711/received_events",
#   "type": "User",
#   "site_admin": false,
#   "name": "Gonzalo Benítez",
#   "company": null,
#   "blog": "",
#   "location": null,
#   "email": null,
#   "hireable": null,
#   "bio": "Hi there! 👋\r\nI'm an Operations associate at Ironhack. where we help people to improve their digital tech skills",
#   "twitter_username": null,
#   "public_repos": 46,
#   "public_gists": 0,
#   "followers": 0,
#   "following": 1,
#   "created_at": "2018-10-29T11:29:35Z",
#   "updated_at": "2023-12-16T23:08:52Z"
# }

# %%
import pandas as pd
json=pd.read_json('output.json',orient='index')
json
# Out:
#                                                                      0
# login                                                       gonzalo711
# id                                                            44572646
# node_id                                           MDQ6VXNlcjQ0NTcyNjQ2
# avatar_url           https://avatars.githubusercontent.com/u/445726...
# gravatar_id
# url                            https://api.github.com/users/gonzalo711
# html_url                                 https://github.com/gonzalo711
# followers_url        https://api.github.com/users/gonzalo711/followers
# following_url        https://api.github.com/users/gonzalo711/follow...
# gists_url            https://api.github.com/users/gonzalo711/gists{...
# starred_url          https://api.github.com/users/gonzalo711/starre...
# subscriptions_url    https://api.github.com/users/gonzalo711/subscr...
# organizations_url         https://api.github.com/users/gonzalo711/orgs
# ...

# %%
#Challenge 2 
import requests

def get_forks_languages(repo_owner, repo_name):
    # Replace with your GitHub username and repository name
    github_username = "gonzalo711"
    github_token = "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"
    
     # Set up the GitHub API endpoint
    api_endpoint = f"https://api.github.com/repos/{repo_owner}/{repo_name}/forks"

    # Set up the headers with authentication
    headers = {
        "Authorization": f"Bearer {github_token}"
    }

    # Send a GET request to the GitHub API to retrieve the list of forks
    response = requests.get(api_endpoint, headers=headers)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        forks = response.json()

        # Create a set to store unique programming languages
        languages_set = set()

        # Loop through each fork and get the languages
        for fork in forks:
            languages_url = fork["languages_url"]
            languages_response = requests.get(languages_url, headers=headers)
            
            if languages_response.status_code == 200:
                languages_data = languages_response.json()
                languages_set.update(languages_data.keys())

        # Convert the set to a list
        languages_list = list(languages_set)

        # Print the list of programming languages
        print(languages_list)

    else:
        print(f"Error: Unable to fetch forks. Status code: {response.status_code}")

# Replace with the actual repository owner and name
repo_owner = "ironhack-datalabs"
repo_name = "bcn-feb-2019"

get_forks_languages(repo_owner, repo_name)
# Out:
# ['Jupyter Notebook', 'HTML', 'Python']

# %%
#Challenge 2

from datetime import datetime, timedelta

def read_token_from_file(file_path):
    with open(file_path, 'r') as file:
        return file.readline().strip()

#3 weeks ago from today
three_weeks_ago = datetime.now() - timedelta(weeks=3)

# Format the date
since_date = three_weeks_ago.isoformat()

github_token = read_token_from_file('token.txt')


headers = {'Authorization': f'token {github_token}'}
url = 'https://api.github.com/repos/ta-data-pt-rmt/lab-mysql-first-queries/commits?since=' + since_date

response = requests.get(url, headers=headers)
commits = response.json()

if response.status_code == 200:
    commits = response.json()
    print(f"Number of commits in the last 3 weeks: {len(commits)}")
else:
    print(f"Failed to fetch commits. Status code: {response.status_code}")
# Out:
# Number of commits in the last 3 weeks: 0
